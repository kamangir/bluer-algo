# %% [markdown]
# # 🪄 bps.stream.estimate_position
#
# [bluer_algo,bps.stream](../bluer_algo/bps/stream.py)

# %%
from bluer_options import string
from bluer_objects import storage
from bluer_objects.storage.policies import DownloadPolicy

from bluer_sandbox.host import signature
from bluer_algo.bps.stream import Stream
from bluer_sandbox.logger import logger

logger.info(f"{'.'.join(signature())},\nbuilt on {string.pretty_date()}")
# Out:
# 🌀  bluer_sandbox-5.521.1.bluer_ai-12.302.1.bluer_objects-6.326.1.bluer_options-5.204.1.blueness-3.118.1.torch-2.2.2.Python 3.12.9.Darwin 23.6.0..Jupyter-Notebook,
# built on 03 November 2025, 10:55:00

# %%
object_name = "2025-11-02-20-53-13-45ycwm"

assert storage.download(
        object_name=object_name,
        policy=DownloadPolicy.DOESNT_EXIST,
    )
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]🌀  ✅ bps-stream.dill
# 🌀  ✅ bps.png
# 🌀  ✅ detections.dill
# 🌀  ✅ detections.yaml
# 🌀  ✅ metadata.yaml
# 🌀  ✅ ultrasonic-sensor-detection.png
# 🌀  ✅ ultrasonic-sensor-distance-mm.png
# 🌀  ✅ ultrasonic-sensor-echo-detection.png
# 🌀  ✅ ultrasonic-sensor-pulse-ms.png
# 🌀  ✅ ultrasonic-sensor-state.png
# 100%|██████████| 10/10 [00:00<00:00, 2564.23it/s]

# %% [markdown]
# ---

# %%
stream = Stream.load(object_name=object_name)
# Out:
# 🪄  loaded 37 ping(s)

# %%
success, position = stream.estimate_position(object_name=object_name)
assert success
# Out:
# 🪄  estimating position from 37 ping(s)...
# 🪄  🪄
# 🪄  position: 0.00,0.00,0.00,1000.00
# 🪄  🎯 0.00,0.00,0.00,1000.00 -> 2025-11-02-20-53-13-45ycwm
# 🌀  bluer_objects.file.save.save_yaml: x, y, z, sigma -> /Users/kamangir/storage/abcli/2025-11-02-20-53-13-45ycwm/position.yaml.

# %% [markdown]
# ---

# %%
# END
